# %%
# 맑은고딕 : Malgun Gothic

# %%
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.font_manager as fm
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
matplotlib.get_configdir()
# Out:
# 'C:\\Users\\user\\.matplotlib'

# %%
matplotlib.get_cachedir()
# Out:
# 'C:\\Users\\user\\.matplotlib'

# %%
data = np.random.randint(-100,100,50).cumsum()
data
# Out:
# array([  92,  101,    7,  -43,   49,   60,   43,   76,    0,  -58,   23,
#          82,  -14,  -78, -149, -114, -118,  -89,  -91,  -55,  -11,  -40,
#         -83,    8,  100,    5,  -71, -100, -188, -198, -146,  -63, -137,
#        -180, -106,  -83,    5,  -81, -147, -153,  -58, -126, -148, -218,
#        -154, -130, -152, -133, -195, -161], dtype=int32)

# %%
plt.plot(range(50),data,'r')
plt.title('시간별 가격 추이')
plt.xlabel('시간')
plt.ylabel('가격')
# Out:
# Text(0, 0.5, '가격')

# %%
fm.findSystemFonts(fontext='ttf')[:4]
# Out:
# ['C:\\Windows\\Fonts\\timesbd.ttf',
#  'C:\\Windows\\Fonts\\PERTIBD.TTF',
#  'C:\\Windows\\Fonts\\FRADMIT.TTF',
#  'C:\\Windows\\Fonts\\BELL.TTF']

# %%
matplotlib.matplotlib_fname()
# Out:
# 'C:\\Users\\user\\anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\matplotlibrc'

# %%
[(f.name,f.fname) for f in fm.fontManager.ttflist if 'Nanum' in f.name]
# Out:
# [('NanumGothic', 'C:\\Windows\\Fonts\\\x7f\x7f\x7f\x7f.TTF'),
#  ('NanumGothic', 'C:\\Windows\\Fonts\\\x7f\x7f\x7f\x7fBOLD.TTF'),
#  ('NanumGothic', 'C:\\Windows\\Fonts\\\x7f\x7f\x7f\x7fEXTRABOLD.TTF'),
#  ('Nanum Pen Script',
#   'C:\\Users\\user\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumPen.ttf'),
#  ('Nanum Brush Script',
#   'C:\\Users\\user\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumBrush.ttf')]

# %%
# 1. font파일이 바로 있는 경우

# %%
path = 'C:\\Users\\user\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumBrush.ttf'
path1= 'C:\\Windows\\Fonts\\\x7f\x7f\x7f\x7f.TTF'
fontporp = fm.FontProperties(fname=path,size=17)
fontporp1 = fm.FontProperties(fname=path1,size=17)
plt.plot(range(50),data,'r')
plt.title('시간별 가격 추이',fontproperties=fontporp)
plt.xlabel('시간',fontproperties=fontporp1)
plt.ylabel('가격',fontproperties=fontporp)
# Out:
# Text(0, 0.5, '가격')

# %%
# 2.

# %%
plt.rcParams['font.family']
# Out:
# ['sans-serif']

# %%
plt.rcParams['font.size']
# Out:
# 10.0

# %%
plt.rcParams['font.family']='Malgun Gothic'
plt.rcParams['font.size']=19

# %%
plt.rcParams['font.family']
# Out:
# ['Malgun Gothic']

# %%
plt.plot(range(50),data,'r')
plt.title('시간별 가격 추이')
plt.xlabel('시간')
plt.ylabel('가격')
# Out:
# Text(0, 0.5, '가격')

# %%
# 3. 설정파일

# %%
matplotlib.matplotlib_fname()
# Out:
# 'C:\\Users\\user\\anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\matplotlibrc'

# %%
matplotlib.rcParams['axes.unicode_minus']=False

# %%
plt.plot(range(50),data,'r')
plt.title('시간별 가격 추이')
plt.xlabel('시간')
plt.ylabel('가격')
# Out:
# Text(0, 0.5, '가격')
